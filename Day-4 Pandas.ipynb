# %%
import pandas as pd

# %%
rivers = ['Ganga','Mississippi','Nile','Kaveri','Yamuan']

# %%
ser_rivers = pd.Series(rivers)

# %%
ser_rivers
# Out:
# 0          Ganga
# 1    Mississippi
# 2           Nile
# 3         Kaveri
# 4         Yamuan
# dtype: object

# %%
type(ser_rivers)
# Out:
# pandas.core.series.Series

# %%
ser_rivers = pd.Series(rivers,index=('riv1','riv2','riv3','riv4','riv5'))

# %%
ser_rivers
# Out:
# riv1          Ganga
# riv2    Mississippi
# riv3           Nile
# riv4         Kaveri
# riv5         Yamuan
# dtype: object

# %%
print(ser_rivers['riv2'])
print(ser_rivers[0])
print(ser_rivers[-1])
# Out:
# Mississippi
# Ganga
# Yamuan

# %%
print(ser_rivers['riv2':'riv4'])#when user provide indexes then both are inclusive
print(ser_rivers[1:4])#implicit indexing second is exclusive
# Out:
# riv2    Mississippi
# riv3           Nile
# riv4         Kaveri
# dtype: object
# riv2    Mississippi
# riv3           Nile
# riv4         Kaveri
# dtype: object

# %%
id(ser_rivers[0])
# Out:
# 3182037201072

# %%
d={'ename':'ABC','eid':102,"esal":100000}
ser_emp=pd.Series(d)
ser_emp
# Out:
# ename       ABC
# eid         102
# esal     100000
# dtype: object

# %%
country=['US','UK','India','UAE','Japan']
capital=['W.DC','London','Delhi','Dubai','Tokiyo']
ser_country_captal=pd.Series(capital,index=country)
ser_country_captal
# Out:
# US         W.DC
# UK       London
# India     Delhi
# UAE       Dubai
# Japan    Tokiyo
# dtype: object

# %%
emp_info={'ename':['jhon','miller','shubham','Richa','David'],'eid':[101,102,103,104,105],"esal":[10000,150000,30000,400000,340000]}
df=pd.DataFrame(emp_info,index=range(1,6))

# %%
df
# Out:
#      ename  eid    esal
# 1     jhon  101   10000
# 2   miller  102  150000
# 3  shubham  103   30000
# 4    Richa  104  400000
# 5    David  105  340000

# %%
df=pd.read_csv('Documents/dataset/ted_data.csv')

# %%
df
# Out:
#                            speaker_name  \
# 0                          Alex Gendler
# 1                           Shari Davis
# 2                      Nita Mosby Tyler
# 3                          Susan Lupack
# 4                         Ariel Waldman
# ...                                 ...
# 2155                       Nancy Frates
# 2156                      Will Marshall
# 2157                        David Grady
# 2158  Vincent Moon and Naná Vasconcelos
# 2159                       Alex Gendler
#
#                                                   title posted_date duration  \
# 0              The Egyptian myth of the death of Osiris    Jul 2020     3:56
# 1     What if you could help decide how the governme...    Jul 2020    10:28
# 2           Want a more just world? Be an unlikely ally    Jul 2020    10:15
# 3              The race to decode a mysterious language    Jul 2020     4:24
# 4     The colorful critter world of microbes in Anta...    Jul 2020     5:56
# ...

# %%
df1=pd.read_excel('Documents/dataset/proj_data.xlsx')

# %%
df1
# Out:
#      GreadBook   Unnamed: 1  Safty test  compony philosophy test  \
# 0          NaN   Max Points        10.0                     20.0
# 1   First Name    Last Name         NaN                      NaN
# 2        Rahul     Gambhire         9.0                     19.0
# 3       Roshan        Madhe         8.0                     20.0
# 4      Shubham        Pawar         7.0                     18.0
# 5      Sharukh        Kumar         9.0                     17.0
# 6         Jhon    Farnandis         8.0                     19.0
# 7          Jay        Shaha         7.0                     19.0
# 8          Ray        Wills         9.0                     17.0
# 9         Kane       Willms         7.0                     16.0
# 10      Harish  Kartikayyan         9.0                     17.0
# 11     Hrithik        Soham         8.0                     18.0
# 12      Pravin       Mhaske         6.0                     19.0
#
# ...

# %%
df1=pd.read_excel('Documents/dataset/proj_data.xlsx','Sheet2')
df1
# Out:
#      GreadBook   Unnamed: 1  Safty test  compony philosophy test  \
# 0          NaN   Max Points        10.0                     20.0
# 1   First Name    Last Name         NaN                      NaN
# 2        Rahul     Gambhire         9.0                     19.0
# 3       Roshan        Madhe         8.0                     20.0
# 4      Shubham        Pawar         7.0                     18.0
# 5      Sharukh        Kumar         9.0                     17.0
# 6         Jhon    Farnandis         8.0                     19.0
# 7          Jay        Shaha         7.0                     19.0
# 8          Ray        Wills         9.0                     17.0
# 9         Kane       Willms         7.0                     16.0
# 10      Harish  Kartikayyan         9.0                     17.0
# 11     Hrithik        Soham         8.0                     18.0
# 12      Pravin       Mhaske         6.0                     19.0
#
# ...

# %%
df1.shape
# Out:
# (13, 11)

# %%
df1.size
# Out:
# 143

# %%
# Out:
#    speaker_name                                     title posted_date  \
# 0  Alex Gendler  The Egyptian myth of the death of Osiris    Jul 2020
#
#   duration                                               Link about_speaker  \
# 0     3:56  https://www.ted.com/talks/alex_gendler_the_egy...           NaN
#
#                                           about_talk    views  \
# 0  Long jealous of his older brother Osiris, the ...  208,703
#
#                              tags
# 0  education,ancient world,TED-Ed

# %%
df.views
# Out:
# 0    208,703
# Name: views, dtype: object

# %%
df1
# Out:
#   GreadBook  Unnamed: 1  Safty test  compony philosophy test  Financial test  \
# 0       NaN  Max Points        10.0                     20.0           100.0
#
#    Drug test  Unnamed: 6  Safty test.1  compony philosophy test.1  \
# 0        1.0         NaN           NaN                        NaN
#
#    Financial test.1  Drug test.1
# 0               NaN          NaN

# %%
df
# Out:
#    speaker_name                                     title posted_date  \
# 0  Alex Gendler  The Egyptian myth of the death of Osiris    Jul 2020
#
#   duration                                               Link about_speaker  \
# 0     3:56  https://www.ted.com/talks/alex_gendler_the_egy...           NaN
#
#                                           about_talk    views  \
# 0  Long jealous of his older brother Osiris, the ...  208,703
#
#                              tags
# 0  education,ancient world,TED-Ed

# %%
df1=pd.read_excel('Documents/dataset/proj_data.xlsx','Sheet2')
df1
# Out:
#      GreadBook   Unnamed: 1  Safty test  compony philosophy test  \
# 0          NaN   Max Points        10.0                     20.0
# 1   First Name    Last Name         NaN                      NaN
# 2        Rahul     Gambhire         9.0                     19.0
# 3       Roshan        Madhe         8.0                     20.0
# 4      Shubham        Pawar         7.0                     18.0
# 5      Sharukh        Kumar         9.0                     17.0
# 6         Jhon    Farnandis         8.0                     19.0
# 7          Jay        Shaha         7.0                     19.0
# 8          Ray        Wills         9.0                     17.0
# 9         Kane       Willms         7.0                     16.0
# 10      Harish  Kartikayyan         9.0                     17.0
# 11     Hrithik        Soham         8.0                     18.0
# 12      Pravin       Mhaske         6.0                     19.0
#
# ...

# %%
df=pd.read_csv('Documents/dataset/ted_data.csv')
df
# Out:
#                            speaker_name  \
# 0                          Alex Gendler
# 1                           Shari Davis
# 2                      Nita Mosby Tyler
# 3                          Susan Lupack
# 4                         Ariel Waldman
# ...                                 ...
# 2155                       Nancy Frates
# 2156                      Will Marshall
# 2157                        David Grady
# 2158  Vincent Moon and Naná Vasconcelos
# 2159                       Alex Gendler
#
#                                                   title posted_date duration  \
# 0              The Egyptian myth of the death of Osiris    Jul 2020     3:56
# 1     What if you could help decide how the governme...    Jul 2020    10:28
# 2           Want a more just world? Be an unlikely ally    Jul 2020    10:15
# 3              The race to decode a mysterious language    Jul 2020     4:24
# 4     The colorful critter world of microbes in Anta...    Jul 2020     5:56
# ...

# %%
df=df.head()

# %%
df
# Out:
#        speaker_name                                              title  \
# 0      Alex Gendler           The Egyptian myth of the death of Osiris
# 1       Shari Davis  What if you could help decide how the governme...
# 2  Nita Mosby Tyler        Want a more just world? Be an unlikely ally
# 3      Susan Lupack           The race to decode a mysterious language
# 4     Ariel Waldman  The colorful critter world of microbes in Anta...
#
#   posted_date duration                                               Link  \
# 0    Jul 2020     3:56  https://www.ted.com/talks/alex_gendler_the_egy...
# 1    Jul 2020    10:28  https://www.ted.com/talks/shari_davis_what_if_...
# 2    Jul 2020    10:15  https://www.ted.com/talks/nita_mosby_tyler_wan...
# 3    Jul 2020     4:24  https://www.ted.com/talks/susan_lupack_the_rac...
# 4    Jul 2020     5:56  https://www.ted.com/talks/ariel_waldman_the_co...
#
#                                        about_speaker  \
# ...

# %%
df.views
# Out:
# 0    208,703
# 1    425,688
# 2    460,269
# 3    350,202
# 4    333,482
# Name: views, dtype: object

# %%
def replace_comma(n):
    
  
        num=n.replace(",","")
        return num

# %%
df['viwes']=df['viwes'].apply(replace_comma)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'viwes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
inter_org=pd.read_csv('Documents/dataset/international_org.csv')

# %%
inter_org
# Out:
#   Organization Name   Headquater
# 0               FAO         Rome
# 1               ICJ    The Hague
# 2               IMF   Washington
# 3            UNESCO        Paris
# 4               UNO     New York
# 5        World Bank   Washington

# %%
inter_org['Founded On']=1945

# %%
inter_org
# Out:
#   Organization Name   Headquater  Founded On
# 0               FAO         Rome        1945
# 1               ICJ    The Hague        1945
# 2               IMF   Washington        1945
# 3            UNESCO        Paris        1945
# 4               UNO     New York        1945
# 5        World Bank   Washington        1945

# %%
del inter_org['Founded On']

# %%
inter_org
# Out:
#   Organization Name   Headquater
# 0               FAO         Rome
# 1               ICJ    The Hague
# 2               IMF   Washington
# 3            UNESCO        Paris
# 4               UNO     New York
# 5        World Bank   Washington

# %%
inter_org1=inter_org.drop(columns=['Founded On'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [91], in <cell line: 1>()
# ----> 1 inter_org1=inter_org.drop(columns=['Founded On'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
moveis_db ={
    
    'Rating':[9.3,9.2,9.1,9.0,8.9,9.8,8.9],
    'title':['The Goadfather','Pirates of carriebien','Real street','The Dark Knight','Schindler list','Fight club','Lion King'],
    'Duration':[142,155,200,175,161,139,191]
}

# %%
df2=pd.DataFrame(moveis_db)
df2
# Out:
#    Rating                  title  Duration
# 0     9.3         The Goadfather       142
# 1     9.2  Pirates of carriebien       155
# 2     9.1            Real street       200
# 3     9.0        The Dark Knight       175
# 4     8.9         Schindler list       161
# 5     9.8             Fight club       139
# 6     8.9              Lion King       191

# %%
df2.loc[2]=[8.7,'Monkey',177]
df2
# Out:
#     Rating                  title  Duration
# 0      9.3         The Goadfather       142
# 1      9.2  Pirates of carriebien       155
# 2      8.7                 Monkey       177
# 3      9.0        The Dark Knight       175
# 4      8.9         Schindler list       161
# 5      9.8             Fight club       139
# 6      8.9              Lion King       191
# 10     8.7                 Monkey       177
# 7      8.7                 Monkey       177

# %%
df2=df2.drop(df2.index[[7]])
df2
# Out:
#    Rating                  title  Duration
# 0     9.3         The Goadfather       142
# 1     9.2  Pirates of carriebien       155
# 2     8.7                 Monkey       177
# 3     9.0        The Dark Knight       175
# 4     8.9         Schindler list       161
# 5     9.8             Fight club       139
# 6     8.9              Lion King       191
# 7     8.7                 Monkey       177

# %%
df2=df2.drop(df2.index[5:7])
df2
# Out:
#    Rating                  title  Duration
# 0     9.3         The Goadfather       142
# 1     9.2  Pirates of carriebien       155
# 2     8.7                 Monkey       177
# 3     9.0        The Dark Knight       175
# 4     8.9         Schindler list       161
# 7     8.7                 Monkey       177

# %%
print(df2.loc[0])
# Out:
# Rating                 9.3
# title       The Goadfather
# Duration               142
# Name: 0, dtype: object

# %%
print(df2.loc[0:3])
# Out:
#    Rating                  title  Duration
# 0     9.3         The Goadfather       142
# 1     9.2  Pirates of carriebien       155
# 2     8.7                 Monkey       177
# 3     9.0        The Dark Knight       175

# %%
#slicing and indexing
df1=pd.read_csv('Downloads/dataset/ted_data.csv')
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [110], in <cell line: 2>()
#       1 #slicing and indexing
# ----> 2 df1=pd.read_csv('Downloads/dataset/ted_data.csv')
#       3 df1
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_csv('Documents/dataset/ted_data.csv')
df
# Out:
#                            speaker_name  \
# 0                          Alex Gendler
# 1                           Shari Davis
# 2                      Nita Mosby Tyler
# 3                          Susan Lupack
# 4                         Ariel Waldman
# ...                                 ...
# 2155                       Nancy Frates
# 2156                      Will Marshall
# 2157                        David Grady
# 2158  Vincent Moon and Naná Vasconcelos
# 2159                       Alex Gendler
#
#                                                   title posted_date duration  \
# 0              The Egyptian myth of the death of Osiris    Jul 2020     3:56
# 1     What if you could help decide how the governme...    Jul 2020    10:28
# 2           Want a more just world? Be an unlikely ally    Jul 2020    10:15
# 3              The race to decode a mysterious language    Jul 2020     4:24
# 4     The colorful critter world of microbes in Anta...    Jul 2020     5:56
# ...

# %%
import matplotlib.pyplot as plt
df=pd.read_csv('Documents/dataset/ted_data.csv')
df.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [118], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 df=pd.read_csv('Documents/dataset/ted_data.csv')
# ----> 3 df.plot()
#       4 plt.show()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
