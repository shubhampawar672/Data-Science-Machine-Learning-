# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Documents/dataset/Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
plt.scatter(df['TV'],df['Sales'],c='red',alpha=0.7,marker='*')

# %%
x=df['TV']

# %%
x=df.iloc[:][['TV']]
x
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
x.shape
# Out:
# (200, 1)

# %%
y=df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (140, 1)

# %%
x_test.shape
# Out:
# (60, 1)

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()

# %%
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model1.predict([[230]])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18.17263062])

# %%
model1.intercept_
# Out:
# 6.831738607257225

# %%
y_predicted=model1.predict(x_train)

# %%
y_predicted
# Out:
# array([20.81555154, 19.79487126, 17.6006552 , 18.14797651, 11.63929066,
#        20.70707344, 15.49519394, 19.90828018, 16.63914479, 18.6706437 ,
#        11.98937906,  7.6798401 ,  8.06937508, 10.09101235, 17.22591268,
#        10.68764189, 13.54751901,  7.19168866,  7.66504763, 17.66968671,
#         8.95199233, 11.46178104, 11.57518996, 17.35411407, 15.94882962,
#        18.6706437 ,  9.9036411 , 16.8166544 ,  7.71435586,  8.95692315,
#        17.50203874, 13.69544369, 15.55929463, 21.11633172,  8.00527439,
#        11.55053585, 21.27411804, 17.69434083,  7.48260719, 21.01278444,
#        17.56613944, 13.02978263, 10.54464804, 18.74953686, 18.63119712,
#        16.46656599, 13.87788412, 15.33740762,  9.29714991, 12.75858739,
#        15.8354207 ,  8.24195387, 13.21222307,  7.75873326,  7.40864485,
#        10.23400621, 13.70037451, 19.7159781 , 14.94294181,  7.78831819,
#        17.35904489,  7.09800303, 17.16674281, 16.3580879 , 18.66078206,
#        12.61066271,  9.66696161, 13.49821078, 17.45273052, 12.90158124,
#        11.05745359,  8.38494773, 13.74968273, 20.8500673 , 11.13141593,
#        12.29015924,  7.21634277, 17.87678126, 11.78228451, 10.59888708,
#        12.12744209, 13.79899096, 19.20317255, 14.89363358,  6.86625437,
#        17.22098185, 16.25454062, 20.3274001 , 19.07990198, 13.45383338,
#        10.55450968, 12.55149284, 16.68352219,  7.79817984, 19.42505956,
#        10.20442128, 17.0336106 , 15.55929463, 19.09962527,  8.7054512 ,
#        17.52176203, 20.64790357, 16.38274201, 16.89554756, 10.59395626,
#        11.18565498,  7.25578935,  8.0940292 ,  7.75380244,  7.03390233,
#        11.89569343, 21.3086338 , 16.57504409, 11.62449819,  9.21332593,
#         7.6798401 , 19.78500961, 14.88377194, 17.96553607, 17.60558602,
#        20.93389128, 18.39451764, 18.08880663, 15.13524389, 15.74666589,
#        16.12140841, 13.29604705, 16.09182348, 16.93992497, 10.31289937,
#        19.92800347,  8.18771483,  9.46972871, 19.3461664 , 10.78625834,
#        10.53478639,  7.26072017, 16.57504409, 14.21811088, 17.7978881 ])

# %%
model1.score(x_train,y_train)
# Out:
# 0.6568964339782305

# %%
df.isnull().sum().sort_values(ascending=False)/df.shape[0]
# Out:
# Unnamed: 0    0.0
# TV            0.0
# Radio         0.0
# Newspaper     0.0
# Sales         0.0
# dtype: float64

# %%
sns.pairplot(data=df,diag_kind='pie')
